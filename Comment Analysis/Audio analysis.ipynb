# %%
pip install librosa
# Out:
# Collecting librosa
#   Downloading librosa-0.8.1-py3-none-any.whl (203 kB)
# Requirement already satisfied: joblib>=0.14 in c:\users\saadi\anaconda3\lib\site-packages (from librosa) (0.17.0)
# Requirement already satisfied: numba>=0.43.0 in c:\users\saadi\anaconda3\lib\site-packages (from librosa) (0.51.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\saadi\anaconda3\lib\site-packages (from librosa) (20.4)
# Collecting audioread>=2.0.0
#   Downloading audioread-2.1.9.tar.gz (377 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: numpy>=1.15.0 in c:\users\saadi\anaconda3\lib\site-packages (from librosa) (1.19.2)
# Requirement already satisfied: decorator>=3.0.0 in c:\users\saadi\anaconda3\lib\site-packages (from librosa) (4.4.2)
# Requirement already satisfied: scikit-learn!=0.19.0,>=0.14.0 in c:\users\saadi\anaconda3\lib\site-packages (from librosa) (0.23.2)
# Collecting resampy>=0.2.2
#   Downloading resampy-0.2.2.tar.gz (323 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: scipy>=1.0.0 in c:\users\saadi\anaconda3\lib\site-packages (from librosa) (1.5.2)
# Collecting pooch>=1.0
#   Downloading pooch-1.5.2-py3-none-any.whl (57 kB)
# Collecting soundfile>=0.10.2
#   Downloading SoundFile-0.10.3.post1-py2.py3.cp26.cp27.cp32.cp33.cp34.cp35.cp36.pp27.pp32.pp33-none-win_amd64.whl (689 kB)
# Requirement already satisfied: llvmlite<0.35,>=0.34.0.dev0 in c:\users\saadi\anaconda3\lib\site-packages (from numba>=0.43.0->librosa) (0.34.0)
# Requirement already satisfied: setuptools in c:\users\saadi\anaconda3\lib\site-packages (from numba>=0.43.0->librosa) (50.3.1.post20201107)
# Requirement already satisfied: six in c:\users\saadi\anaconda3\lib\site-packages (from packaging>=20.0->librosa) (1.15.0)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\saadi\anaconda3\lib\site-packages (from packaging>=20.0->librosa) (2.4.7)
# Collecting appdirs
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: requests in c:\users\saadi\anaconda3\lib\site-packages (from pooch>=1.0->librosa) (2.24.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\saadi\anaconda3\lib\site-packages (from scikit-learn!=0.19.0,>=0.14.0->librosa) (2.1.0)
# Requirement already satisfied: cffi>=1.0 in c:\users\saadi\anaconda3\lib\site-packages (from soundfile>=0.10.2->librosa) (1.14.3)
# Requirement already satisfied: pycparser in c:\users\saadi\anaconda3\lib\site-packages (from cffi>=1.0->soundfile>=0.10.2->librosa) (2.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\saadi\anaconda3\lib\site-packages (from requests->pooch>=1.0->librosa) (1.25.11)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\saadi\anaconda3\lib\site-packages (from requests->pooch>=1.0->librosa) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\saadi\anaconda3\lib\site-packages (from requests->pooch>=1.0->librosa) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\saadi\anaconda3\lib\site-packages (from requests->pooch>=1.0->librosa) (3.0.4)
# Building wheels for collected packages: audioread, resampy
#   Building wheel for audioread (setup.py): started
#   Building wheel for audioread (setup.py): finished with status 'done'
#   Created wheel for audioread: filename=audioread-2.1.9-py3-none-any.whl size=23146 sha256=230c3cebc7ee0b808ebad5a5c914cc92eedbe00a349ba58f607aba45737df2b6
#   Stored in directory: c:\users\saadi\appdata\local\pip\cache\wheels\49\5a\e4\df590783499a992a88de6c0898991d1167453a3196d0d1eeb7
#   Building wheel for resampy (setup.py): started
#   Building wheel for resampy (setup.py): finished with status 'done'
#   Created wheel for resampy: filename=resampy-0.2.2-py3-none-any.whl size=320724 sha256=3977bcc37ff5c8b9e443439e9ca7852e187ea439334b4956f42ebc6558474fc0
#   Stored in directory: c:\users\saadi\appdata\local\pip\cache\wheels\6f\d1\5d\f13da53b1dcbc2624ff548456c9ffb526c914f53c12c318bb4
# Successfully built audioread resampy
# Installing collected packages: appdirs, soundfile, resampy, pooch, audioread, librosa
# Successfully installed appdirs-1.4.4 audioread-2.1.9 librosa-0.8.1 pooch-1.5.2 resampy-0.2.2 soundfile-0.10.3.post1
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.io.wavfile import read, write
from IPython.display import Audio
from numpy.fft import fft, ifft
# %matplotlib inline

Fs, data = read("my_result.wav")
data = data[:,0]

plt.figure()
plt.plot(data)

plt.show()

import librosa
#audio_data = r"my_result.wav"
x , sr = librosa.load(data)
print(type(x), type(sr))#<class 'numpy.ndarray'> <class 'int'>print(x.shape, sr)#(94316,) 22050

# %matplotlib inline
import matplotlib.pyplot as plt
import librosa.display
plt.figure(figsize=(14, 5))
librosa.display.waveplot(x, sr=sr)
print(x)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-30e0f8fdd36f> in <module>
#       6 get_ipython().run_line_magic('matplotlib', 'inline')
#       7
# ----> 8 Fs, data = read("my_result.wav")
#       9 data = data[:,0]
#      10
#
# ~\anaconda3\lib\site-packages\scipy\io\wavfile.py in read(filename, mmap)
#     542         mmap = False
#     543     else:
# --> 544         fid = open(filename, 'rb')
#     545
#     546     try:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'my_result.wav'

# %%
for i in range(10):
    
    
    Fs, data = read(f"{i}.wav")
    data = data[:,0]

    plt.figure()
    plt.plot(data)

    plt.show()

    import librosa
    #audio_data = r"my_result.wav"
    x , sr = librosa.load(f"{i}.wav")
    print(type(x), type(sr))#<class 'numpy.ndarray'> <class 'int'>print(x.shape, sr)#(94316,) 22050

    # %matplotlib inline
    import matplotlib.pyplot as plt
    import librosa.display
    plt.figure(figsize=(14, 5))
    librosa.display.waveplot(x, sr=sr)
    print(x)
# Out:
# <class 'numpy.ndarray'> <class 'int'>
# [0. 0. 0. ... 0. 0. 0.]
# <class 'numpy.ndarray'> <class 'int'>
# [ 0.0000000e+00  0.0000000e+00  0.0000000e+00 ... -1.3331245e-04
#  -4.6509427e-05  2.9413204e-05]
# <class 'numpy.ndarray'> <class 'int'>
# [ 0.          0.          0.         ... -0.00051057 -0.00049485
#   0.        ]
# <class 'numpy.ndarray'> <class 'int'>
# [0. 0. 0. ... 0. 0. 0.]
# <class 'numpy.ndarray'> <class 'int'>
# [0. 0. 0. ... 0. 0. 0.]
# <class 'numpy.ndarray'> <class 'int'>
# [ 0.000000e+00  0.000000e+00  0.000000e+00 ... -5.792106e-05 -6.660494e-05
#   0.000000e+00]
# <class 'numpy.ndarray'> <class 'int'>
# [ 0.0000000e+00  0.0000000e+00  0.0000000e+00 ... -1.4655326e-05
#  -1.6775772e-05  0.0000000e+00]
# <class 'numpy.ndarray'> <class 'int'>
# [-0.00724856 -0.00900712 -0.00367077 ...  0.          0.
#   0.        ]
# <class 'numpy.ndarray'> <class 'int'>
# [ 0.0000000e+00  0.0000000e+00  0.0000000e+00 ... -2.9088178e-05
#  -3.3414985e-05  0.0000000e+00]
# <class 'numpy.ndarray'> <class 'int'>
# [0.0000000e+00 0.0000000e+00 0.0000000e+00 ... 2.1970785e-05 3.1899159e-05
#  0.0000000e+00]

# %%
ranges = [[((290, 300), 31),
  ((300, 310), 33),
  ((380, 390), 76),
  ((200, 210), 49),
  ((370, 380), 39)],
 [((170, 180), 1),
  ((10, 20), 1),
  ((180, 190), 1),
  ((0, 10), 39),
  ((30, 40), 1)],
 [((460, 470), 26),
  ((250, 260), 38),
  ((630, 640), 33),
  ((490, 500), 38),
  ((480, 490), 60)],
 [((30, 40), 1),
  ((920, 930), 3),
  ((190, 200), 3),
  ((910, 920), 4),
  ((660, 670), 7)],
 [((20, 30), 0), ((30, 40), 1), ((50, 60), 1), ((0, 10), 23), ((40, 50), 1)],
 [((20, 30), 12),
  ((40, 50), 15),
  ((0, 10), 17),
  ((10, 20), 17),
  ((70, 80), 17)],
 [((80, 90), 13),
  ((30, 40), 16),
  ((100, 110), 29),
  ((0, 10), 23),
  ((90, 100), 150)],
 [((30, 40), 5),
  ((40, 50), 6),
  ((60, 70), 7),
  ((100, 110), 44),
  ((110, 120), 10)],
 [((40, 50), 6),
  ((60, 70), 8),
  ((70, 80), 7),
  ((50, 60), 8),
  ((150, 160), 15)],
 [((640, 650), 3),
  ((120, 130), 3),
  ((200, 210), 7),
  ((30, 40), 5),
  ((20, 30), 5)]]

# %%
# Out:
# ((290, 300), 31)
